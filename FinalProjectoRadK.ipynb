# %% [markdown]
# # Final Project based on Pesticide use in American Farming
# ##Data taken from Kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
from sklearn.datasets import make_regression
# %matplotlib inline

# %%
df = pd.read_csv('2014.csv')

# %%
df2 = pd.read_csv('2015.csv')

# %%
df3 = pd.read_csv('dictionary.csv')

# %%
#I read in the files, and had a look into how i can succesfully merge it

# %%
df.head
# Out:
# <bound method NDFrame.head of         COMPOUND  YEAR  STATE_CODE  COUNTY_CODE  LOW_ESTIMATE  HIGH_ESTIMATE
# 0          2,4-D  2014           1            1        1698.6         1885.5
# 1          2,4-D  2014           1            3        7513.6         8472.4
# 2          2,4-D  2014           1            5        2613.6         2889.4
# 3          2,4-D  2014           1            7        1259.2         1277.7
# 4          2,4-D  2014           1            9        7590.5         7756.1
# 5          2,4-D  2014           1           11        1318.9         1408.5
# 6          2,4-D  2014           1           13        2798.2         2805.0
# 7          2,4-D  2014           1           15        3130.4         3335.5
# 8          2,4-D  2014           1           17        4784.1         4813.8
# 9          2,4-D  2014           1           19        4220.3         4977.2
# 10         2,4-D  2014           1           21        3417.8         3476.7
# ...

# %%
df2.head
# Out:
# <bound method NDFrame.head of                      COMPOUND  YEAR  STATE_CODE  COUNTY_CODE  LOW_ESTIMATE  \
# 0       1-Methyl Cyclopropene  2015          41            1           NaN
# 1       1-Methyl Cyclopropene  2015          41           21           NaN
# 2       1-Methyl Cyclopropene  2015          41           27           NaN
# 3       1-Methyl Cyclopropene  2015          41           49           NaN
# 4       1-Methyl Cyclopropene  2015          41           55           NaN
# 5       1-Methyl Cyclopropene  2015          41           59           NaN
# 6       1-Methyl Cyclopropene  2015          41           61           NaN
# 7       1-Methyl Cyclopropene  2015          41           63           NaN
# 8       1-Methyl Cyclopropene  2015          41           65           NaN
# 9       1-Methyl Cyclopropene  2015          53            1           NaN
# 10      1-Methyl Cyclopropene  2015          53            3           0.0
# ...

# %%
df3.index
# Out:
# RangeIndex(start=0, stop=3235, step=1)

# %%
pd.DataFrame(df, df2)
##This data frame merges both files
# Out:
#                                                  COMPOUND  YEAR  STATE_CODE  \
# (1-Methyl Cyclopropene, 2015, 41, 1, nan, 0.0)        NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 21, nan, 0.1)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 27, nan, 1.7)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 49, nan, 0.1)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 55, nan, 0.0)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 59, nan, 5.7)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 61, nan, 0.0)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 63, nan, 0.0)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 41, 65, nan, 0.1)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 53, 1, nan, 10.6)       NaN   NaN         NaN
# (1-Methyl Cyclopropene, 2015, 53, 3, 0.0, 0.0)        NaN   NaN         NaN
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
graph = make_regression(n_features =50)

# %%
X = graph[0][: , 30]
y = graph[0][: , 30]

# %%
plt.scatter(X, y)

# %%
#Fitting a linear regression model, by fitting and making predictions towards data

# %%
lr = LinearRegression()

# %%
lr.fit(X.reshape(-1,1), y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = lr.predict(X.reshape(-1,1))

# %%
plt.scatter(X, y)
plt.plot(X, y_pred)
#plotting a best fit line for the data

# %%
lr.coef_
lr.intercept_
# Out:
# 2.7755575615628914e-17

# %%
#todo: feature engineering and adding lasso, and ridge regression

# %%
df.dtypes
# Out:
# COMPOUND          object
# YEAR               int64
# STATE_CODE         int64
# COUNTY_CODE        int64
# LOW_ESTIMATE     float64
# HIGH_ESTIMATE    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392433 entries, 0 to 392432
# Data columns (total 6 columns):
# COMPOUND         392433 non-null object
# YEAR             392433 non-null int64
# STATE_CODE       392433 non-null int64
# COUNTY_CODE      392433 non-null int64
# LOW_ESTIMATE     273406 non-null float64
# HIGH_ESTIMATE    392433 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 18.0+ MB

# %% [markdown]
# # A function used to calculate the average of the compound high estimate

# %%
def Average(High_Estimate):
    if len(High_Estimate) == 0:
        return None:
        return sum(High_Estimate) ? len(High_Estimate)

# %% [markdown]
# ## Feature Engineering

# %%
HighOutcome = df[['YEAR', 'HIGH_ESTIMATE', 'LOW_ESTIMATE']]
HighOutcome.sort_index()
# Out:
#         YEAR  HIGH_ESTIMATE  LOW_ESTIMATE
# 0       2014         1885.5        1698.6
# 1       2014         8472.4        7513.6
# 2       2014         2889.4        2613.6
# 3       2014         1277.7        1259.2
# 4       2014         7756.1        7590.5
# 5       2014         1408.5        1318.9
# 6       2014         2805.0        2798.2
# 7       2014         3335.5        3130.4
# 8       2014         4813.8        4784.1
# 9       2014         4977.2        4220.3
# 10      2014         3476.7        3417.8
# 11      2014         1018.7        1018.0
# 12      2014          821.9         820.9
# 13      2014         4102.1        4097.6
# 14      2014         2303.5        2286.9
# 15      2014         4577.8        3747.3
# 16      2014        13851.8       13796.7
# 17      2014         2200.4        2148.5
# 18      2014         1422.9        1421.6
# 19      2014         3135.2        2676.7
# 20      2014         2325.7        2098.4
# ...

# %%
HighOutcome.plot.hist()
#Compares the total growth of the highest estimates of pesticides used and the lowest pesticide use

# %%
GoodYear = df['YEAR'] + df['LOW_ESTIMATE']

# %%
BadYear = df['YEAR'] + df['HIGH_ESTIMATE']

# %%
#creating variables to determine which years were better based on amount of pesticide used

# %%
#plot a estimated compund graph based on county
#implement linear regression methods and others such as lasso & ridge
#Test newly created function
